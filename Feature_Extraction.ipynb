# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
df = pd.read_csv("C:\\Users\\Rahul\\Desktop\\IPL\\output.csv")

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#           city                     venue
# 0          NaN  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
# ...

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city  current_score
# 0      Melbourne              0
# 1      Melbourne              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city  current_score over ball_no
# 0      Melbourne              0    0       1
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city  current_score over ball_no  balls_bowled
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                 0
# 1             2    Australia    Sri Lanka   0.2     0                 0
# 2             2    Australia    Sri Lanka   0.3     1                 0
# 3             2    Australia    Sri Lanka   0.4     2                 0
# 4             2    Australia    Sri Lanka   0.5     0                 0
# ...         ...          ...          ...   ...   ...               ...
# 63883       964    Sri Lanka    Australia  19.3     1                 8
# 63884       964    Sri Lanka    Australia  19.4     0                 8
# 63885       964    Sri Lanka    Australia  19.5     0                 9
# 63886       964    Sri Lanka    Australia  19.6     2                 9
# 63887       964    Sri Lanka    Australia  19.7     1                 9
#
#             city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# ...

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(5)
# Out:
#       batting_team  bowling_team             city  current_score  balls_left  \
# 28848     Pakistan  South Africa        Abu Dhabi             90          36
# 27519      England      Pakistan            Dubai            110          24
# 13531  New Zealand   West Indies  Mount Maunganui            216          10
# 3906      Pakistan   New Zealand       Wellington             22          88
# 50087    Sri Lanka      Pakistan           Mirpur             58          70
#
#        wickets_left  last_five  runs_x
# 28848             4       28.0     119
# 27519             9       31.0     148
# 13531             8       65.0     238
# 3906              7       21.0     105
# 50087            10       45.0     150

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X
# Out:
#        batting_team bowling_team         city  current_score  balls_left  \
# 5722     Bangladesh        India      Colombo            126          10
# 34762   West Indies  New Zealand   Lauderhill            208           1
# 1671    West Indies     Pakistan    Abu Dhabi             43          61
# 43637  South Africa   Bangladesh       Mirpur             88          63
# 47022      Pakistan   Bangladesh      Kolkata             54          84
# ...             ...          ...          ...            ...         ...
# 42434   New Zealand     Pakistan        Dubai            110          29
# 17396     Sri Lanka    Australia    Cape Town             99           9
# 8060    New Zealand        India     Auckland            133          21
# 12051       England    Australia  Southampton            113          27
# 37536   West Indies      England     Barbados            132          17
#
#        wickets_left  last_five
# 5722              4       30.0
# ...

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 9861      Australia  South Africa  Johannesburg            116          46
# 11664         India   West Indies    Lauderhill            108          45
# 23894      Pakistan    Bangladesh      St Lucia             71          67
# 38428   New Zealand   West Indies      Auckland            110          37
# 22578     Sri Lanka         India       Colombo            119          33
# ...             ...           ...           ...            ...         ...
# 48664       England     Sri Lanka         Delhi            106          27
# 48307     Australia      Pakistan    Chandigarh            142          20
# 46027      Pakistan   New Zealand      Hamilton            127          25
# 3621      Sri Lanka         India       Colombo             74          68
# 7144   South Africa     Sri Lanka  Johannesburg             69          61
#
#        wickets_left  last_five
# 9861              7       35.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error , accuracy_score

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# ...
# Using cached xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
# ...

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                 1
# 1             2    Australia    Sri Lanka   0.2     0                 2
# 2             2    Australia    Sri Lanka   0.3     1                 3
# 3             2    Australia    Sri Lanka   0.4     2                 4
# 4             2    Australia    Sri Lanka   0.5     0                 5
# ...         ...          ...          ...   ...   ...               ...
# 63883       964    Sri Lanka    Australia  19.3     1               122
# 63884       964    Sri Lanka    Australia  19.4     0               123
# 63885       964    Sri Lanka    Australia  19.5     0               124
# 63886       964    Sri Lanka    Australia  19.6     2               125
# 63887       964    Sri Lanka    Australia  19.7     1               126
#
#             city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
NUMERICAL_FEATURES = X.select_dtypes(include=['number']).columns
CATEGORICAL_FEATURES = X.select_dtypes(include=['object', 'category']).columns

# %%
CATEGORICAL_FEATURES
# Out:
# Index(['batting_team', 'bowling_team', 'city'], dtype='object')

# %%
NUMERICAL_FEATURES
# Out:
# Index(['current_score', 'balls_left', 'wickets_left', 'last_five'], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV


numerical_transformer = Pipeline(steps=[
    ('scaling', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('scaling', OneHotEncoder())
])

preprocessing = ColumnTransformer(transformers=[
    ('numerical', numerical_transformer, NUMERICAL_FEATURES),
    ('categorical', categorical_transformer, CATEGORICAL_FEATURES)
],remainder = "passthrough")

# Define the Pipeline
pipe = Pipeline(steps=[
    ('preprocessing', preprocessing),
    ('model', XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numerical',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['current_score', 'balls_left', 'wickets_left', 'last_five'], dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('scaling',
#                                                                    OneHotEncoder())]),
#                                                   Index(['batting_team', 'bowling_team', 'city'], dtype='object'...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
# ...

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9833472248614779
# 2.267773345701412

# %%
model = pickle.dump(pipe,open('pipe7.pkl','wb'))

# %%
model = pickle.load(open("pipe7.pkl","rb"))

# %%
import pandas as pd

# Assuming your model expects columns with specific names, create a DataFrame
data = pd.DataFrame([["Afghanistan", "Sri Lanka", "Kolkata", 124, 11, 5, 47.0]],
                    columns=["batting_team", "bowling_team", "city", "current_score", "balls_left", "wickets_left", "last_five"])

# Now, you can make predictions using your model
predictions = model.predict(data)[0]
print(predictions)
# Out:
# 145.9351

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numerical',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   ['current_score',
#                                                    'wickets_left', 'last_five',
#                                                    'balls_left']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('scaling',
#                                                                    OneHotEncoder())]),
#                                                   Index(['batting_team', 'bowling_team', 'city'], dtype='object'))])),
#                 ('model',
#                  XGBRegr...
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# alembic                       1.13.1
# altair                        5.1.1
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# aniso8601                     9.0.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# autocorrect                   2.6.1
# Automat                       20.2.0
# autopep8                      1.6.0
# ...

# %%
# !!pip install --upgrade --force-reinstall scikit-learn
# Out:
# ['Collecting scikit-learn',
#  '  Downloading scikit_learn-1.4.2-cp39-cp39-win_amd64.whl (10.6 MB)',
#  'Collecting threadpoolctl>=2.0.0',
#  '  Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)',
#  'Collecting numpy>=1.19.5',
#  '  Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)',
#  'Collecting scipy>=1.6.0',
#  '  Downloading scipy-1.13.0-cp39-cp39-win_amd64.whl (46.2 MB)',
#  'Collecting joblib>=1.2.0',
#  '  Downloading joblib-1.4.2-py3-none-any.whl (301 kB)',
#  'Installing collected packages: numpy, threadpoolctl, scipy, joblib, scikit-learn',
#  '  Attempting uninstall: numpy',
#  '    Found existing installation: numpy 1.22.4',
#  '    Uninstalling numpy-1.22.4:',
#  '      Successfully uninstalled numpy-1.22.4',
#  "ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\\\Users\\\\Rahul\\\\anaconda3\\\\Lib\\\\site-packages\\\\~~mpy\\\\.libs\\\\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll'",
# ...
